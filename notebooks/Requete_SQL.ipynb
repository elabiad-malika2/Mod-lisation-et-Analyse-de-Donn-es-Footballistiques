# %%
import pandas as pd
from sqlalchemy import create_engine, MetaData, Table, select, func, desc, case

# ================================
# Connexion à la base PostgreSQL
# ================================
engine = create_engine("postgresql+psycopg2://postgres:malika123@localhost:5432/footballistiques")
metadata = MetaData()

# ================================
#  Référencer les tables existantes
# ================================
saison = Table("saison", metadata, autoload_with=engine)
competition = Table("competition", metadata, autoload_with=engine)
team = Table("team", metadata, autoload_with=engine)
player = Table("player", metadata, autoload_with=engine)
match = Table("match", metadata, autoload_with=engine)
match_result = Table("match_result", metadata, autoload_with=engine)
player_statistics = Table("player_statistics", metadata, autoload_with=engine)

# %% [markdown]
# Top 10 des meilleurs buteurs — Identifier les joueurs ayant marqué le plus de buts.

# %%
from sqlalchemy import select, func, desc

# Construire la requête Core (même logique que celle avec Session)
stmt = (select(
    player.c.Player,
    team.c.team_name,
    func.sum(player_statistics.c.Gls).label("total_buts")
).join(player_statistics, player_statistics.c.player_id == player.c.player_id
).join(team, player.c.team_id == team.c.team_id
).group_by(player.c.Player, team.c.team_name
).order_by(desc("total_buts"))
.limit(10))


# Exécuter la requête sans session
with engine.connect() as conn:
    results = conn.execute(stmt).fetchall()

# Afficher le Top 10
for joueur, equipe, total_buts in results:
    print(f"{joueur} ({equipe}) - {total_buts} buts")
# Out:
# Mohamed Salah (Liverpool) - 58.0 buts
# Alexander Isak (Newcastle Utd) - 46.0 buts
# Erling Haaland (Manchester City) - 44.0 buts
# Chris Wood (Nott'ham Forest) - 40.0 buts
# Bryan Mbeumo (Brentford) - 40.0 buts
# Yoane Wissa (Brentford) - 38.0 buts
# Ollie Watkins (Aston Villa) - 32.0 buts
# Cole Palmer (Chelsea) - 30.0 buts
# Matheus Cunha (Wolves) - 30.0 buts
# Jørgen Strand Larsen (Wolves) - 28.0 buts

# %% [markdown]
# Joueurs les plus décisifs (buts + passes décisives)

# %%
from sqlalchemy import select, func, desc

stmt = select(
    player.c.Player,
    team.c.team_name,
    (func.sum(player_statistics.c.Gls) + func.sum(player_statistics.c.Ast)).label("total_decisive")
).join(player_statistics, player.c.player_id == player_statistics.c.player_id
).join(team, player.c.team_id == team.c.team_id
).group_by(player.c.Player, team.c.team_name
).order_by(desc("total_decisive")
).limit(3)

with engine.connect() as conn:
    results = conn.execute(stmt).fetchall()
print(results)
# Out:
# [('Mohamed Salah', 'Liverpool', 94.0), ('Alexander Isak', 'Newcastle Utd', 58.0), ('Bryan Mbeumo', 'Brentford', 54.0)]

# %% [markdown]
# Répartition des nationalités des joueurs par équipe

# %%
stmt = select(
    team.c.team_name,
    player.c.Nation,
    func.count(player.c.player_id).label("nb_joueurs")
).join(player, player.c.team_id == team.c.team_id
).group_by(team.c.team_name, player.c.Nation
).order_by(team.c.team_name, func.count(player.c.player_id).desc())

with engine.connect() as conn:
    results = conn.execute(stmt).fetchall()

for team_name, Nation, nb_joueurs in results:
    print(f"{team_name} ({Nation}) - {nb_joueurs} players")
# Out:
# Arsenal (ENG) - 16 players
# Arsenal (BRA) - 4 players
# Arsenal (ITA) - 2 players
# Liverpool (IRL) - 1 players
# Liverpool (EGY) - 1 players
# Liverpool (NIR) - 1 players
# Liverpool (POR) - 1 players
# Liverpool (JPN) - 1 players
# Liverpool (ITA) - 1 players
# Liverpool (FRA) - 1 players
# Liverpool (SCO) - 1 players
# Liverpool (BRA) - 1 players
# Liverpool (ARG) - 1 players
# Manchester City (ENG) - 14 players
# Manchester City (BRA) - 3 players
# Manchester City (POR) - 3 players
# Manchester City (CRO) - 2 players
# Manchester City (NOR) - 2 players
# Manchester City (BEL) - 2 players
# Manchester City (ESP) - 2 players
# Manchester City (GER) - 2 players
# Manchester City (SUI) - 1 players
# Manchester City (ARG) - 1 players
# Manchester City (NED) - 1 players
# Manchester City (EGY) - 1 players
# Manchester City (UZB) - 1 players
# Manchester City (BFA) - 1 players
# Manchester Utd (ENG) - 16 players
# Manchester Utd (DEN) - 4 players
# Manchester Utd (NED) - 3 players
# Manchester Utd (NIR) - 2 players
# Manchester Utd (BRA) - 2 players
# Manchester Utd (ARG) - 2 players
# Manchester Utd (POR) - 2 players
# Manchester Utd (SCO) - 1 players
# Manchester Utd (CMR) - 1 players
# Manchester Utd (MLI) - 1 players
# Manchester Utd (URU) - 1 players
# Manchester Utd (SWE) - 1 players
# Manchester Utd (FRA) - 1 players
# Manchester Utd (POL) - 1 players
# Manchester Utd (MAR) - 1 players
# Manchester Utd (TUR) - 1 players
# Manchester Utd (CIV) - 1 players
# Newcastle Utd (ENG) - 18 players
# Newcastle Utd (BRA) - 2 players
# Newcastle Utd (SWE) - 2 players
# Newcastle Utd (SUI) - 1 players
# Newcastle Utd (DEN) - 1 players
# Newcastle Utd (NED) - 1 players
# Newcastle Utd (PAR) - 1 players
# Newcastle Utd (ITA) - 1 players
# Newcastle Utd (IRL) - 1 players
# Newcastle Utd (GRE) - 1 players
# Newcastle Utd (SVK) - 1 players
# Nott'ham Forest (ENG) - 7 players
# Nott'ham Forest (BRA) - 4 players
# Nott'ham Forest (NGA) - 2 players
# Nott'ham Forest (CIV) - 2 players
# Nott'ham Forest (WAL) - 2 players
# Nott'ham Forest (GER) - 1 players
# Nott'ham Forest (IRL) - 1 players
# Nott'ham Forest (BEL) - 1 players
# Nott'ham Forest (SWE) - 1 players
# Nott'ham Forest (SRB) - 1 players
# Nott'ham Forest (ARG) - 1 players
# Nott'ham Forest (PAR) - 1 players
# Nott'ham Forest (ESP) - 1 players
# Nott'ham Forest (NZL) - 1 players
# Nott'ham Forest (POR) - 1 players
# Southampton (ENG) - 18 players
# Southampton (IRL) - 3 players
# Southampton (FRA) - 2 players
# Southampton (SCO) - 2 players
# Southampton (NGA) - 2 players
# Southampton (Unknown) - 1 players
# Southampton (JPN) - 1 players
# Southampton (CIV) - 1 players
# Southampton (POL) - 1 players
# Southampton (CHI) - 1 players
# Southampton (GHA) - 1 players
# Southampton (ARG) - 1 players
# Southampton (POR) - 1 players
# Southampton (DEN) - 1 players
# Southampton (BRA) - 1 players
# Southampton (GER) - 1 players
# Tottenham (ENG) - 17 players
# Tottenham (KOR) - 2 players
# Tottenham (ITA) - 2 players
# Tottenham (FRA) - 2 players
# Tottenham (WAL) - 2 players
# Tottenham (ESP) - 2 players
# Tottenham (SWE) - 2 players
# Tottenham (JAM) - 1 players
# Tottenham (ROU) - 1 players
# Tottenham (GER) - 1 players
# Tottenham (CZE) - 1 players
# Tottenham (NED) - 1 players
# Tottenham (URU) - 1 players
# Tottenham (BRA) - 1 players
# Tottenham (MLI) - 1 players
# Tottenham (ARG) - 1 players
# Tottenham (SEN) - 1 players
# Tottenham (AUT) - 1 players
# West Ham (ENG) - 9 players
# West Ham (BRA) - 2 players
# West Ham (CZE) - 2 players
# West Ham (FRA) - 2 players
# West Ham (POL) - 1 players
# West Ham (GHA) - 1 players
# West Ham (IRL) - 1 players
# West Ham (GER) - 1 players
# West Ham (GRE) - 1 players
# West Ham (ESP) - 1 players
# West Ham (ARG) - 1 players
# West Ham (JAM) - 1 players
# West Ham (SCO) - 1 players
# West Ham (NED) - 1 players
# West Ham (COD) - 1 players
# West Ham (ITA) - 1 players
# West Ham (MEX) - 1 players
# West Ham (BRB) - 1 players
# Wolves (POR) - 8 players
# Wolves (ENG) - 8 players
# Wolves (BRA) - 4 players
# Wolves (ZIM) - 2 players
# Wolves (GAB) - 1 players
# Wolves (COL) - 1 players
# Wolves (ESP) - 1 players
# Wolves (URU) - 1 players
# Wolves (ALG) - 1 players
# Wolves (IRL) - 1 players
# Wolves (HAI) - 1 players
# Wolves (FRA) - 1 players
# Wolves (CIV) - 1 players
# Wolves (WAL) - 1 players
# Wolves (BFA) - 1 players
# Wolves (KOR) - 1 players
# Wolves (MLI) - 1 players
# Wolves (NOR) - 1 players
# Wolves (Unknown) - 1 players

# %% [markdown]
# Nombre total de buts par équipe

# %%
stmt = select(
    team.c.team_name,
    func.sum(player_statistics.c.Gls).label("total_buts")
).join(player, player.c.team_id == team.c.team_id
).join(player_statistics, player_statistics.c.player_id == player.c.player_id
).group_by(team.c.team_name
).order_by(desc("total_buts"))

with engine.connect() as conn:
    results = conn.execute(stmt).fetchall()

for team_name, total_buts in results:
    print(f"{team_name} : {total_buts} buts")
# Out:
# Liverpool : 170.0 buts
# Manchester City : 142.0 buts
# Arsenal : 134.0 buts
# Newcastle Utd : 132.0 buts
# Brentford : 130.0 buts
# Brighton : 128.0 buts
# Tottenham : 122.0 buts
# Chelsea : 120.0 buts
# Bournemouth : 114.0 buts
# Nott'ham Forest : 114.0 buts
# Aston Villa : 112.0 buts
# Wolves : 106.0 buts
# Fulham : 104.0 buts
# West Ham : 86.0 buts
# Crystal Palace : 86.0 buts
# Manchester Utd : 80.0 buts
# Everton : 78.0 buts
# Ipswich Town : 62.0 buts
# Leicester City : 56.0 buts
# Southampton : 54.0 buts

# %% [markdown]
# Moyenne de buts marqués et encaissés par match

# %%
stmt = select(
    team.c.team_name,
    func.avg(match_result.c.GF).label("moy_buts_marques"),
    func.avg(match_result.c.GA).label("moy_buts_encais")
).join(match, match.c.team_id == team.c.team_id
).join(match_result, match_result.c.match_id == match.c.match_id
).group_by(team.c.team_name)

with engine.connect() as conn:
    results = conn.execute(stmt).fetchall()

for team_name, moy_buts_marques, moy_buts_encais in results:
    print(f"{team_name} ( moyenne buts marques: {moy_buts_marques} - moyenne buts encais {moy_buts_encais} ) ")
# Out:
# Bournemouth ( moyenne buts marques: 1.2105263157894737 - moyenne buts encais 0.84210526315789473684 )
# Nott'ham Forest ( moyenne buts marques: 1.3684210526315789 - moyenne buts encais 0.84210526315789473684 )
# Manchester City ( moyenne buts marques: 2.2631578947368421 - moyenne buts encais 1.2105263157894737 )
# Manchester Utd ( moyenne buts marques: 1.2105263157894737 - moyenne buts encais 1.4736842105263158 )
# Tottenham ( moyenne buts marques: 1.8421052631578947 - moyenne buts encais 1.8421052631578947 )
# Everton ( moyenne buts marques: 1.3684210526315789 - moyenne buts encais 1.2105263157894737 )
# Fulham ( moyenne buts marques: 1.4210526315789474 - moyenne buts encais 1.5789473684210526 )
# Brentford ( moyenne buts marques: 2.1052631578947368 - moyenne buts encais 1.8421052631578947 )
# Ipswich Town ( moyenne buts marques: 0.73684210526315789474 - moyenne buts encais 2.3157894736842105 )
# Brighton ( moyenne buts marques: 1.5789473684210526 - moyenne buts encais 1.3684210526315789 )
# Wolves ( moyenne buts marques: 1.4210526315789474 - moyenne buts encais 1.6842105263157895 )
# Newcastle Utd ( moyenne buts marques: 2.1052631578947368 - moyenne buts encais 1.0526315789473684 )
# Aston Villa ( moyenne buts marques: 1.7894736842105263 - moyenne buts encais 1.0526315789473684 )
# Crystal Palace ( moyenne buts marques: 1.2631578947368421 - moyenne buts encais 1.3684210526315789 )
# Arsenal ( moyenne buts marques: 1.8421052631578947 - moyenne buts encais 0.89473684210526315789 )
# Southampton ( moyenne buts marques: 0.68421052631578947368 - moyenne buts encais 2.4736842105263158 )
# Chelsea ( moyenne buts marques: 1.8421052631578947 - moyenne buts encais 0.94736842105263157895 )
# West Ham ( moyenne buts marques: 1.2105263157894737 - moyenne buts encais 1.7894736842105263 )
# Leicester City ( moyenne buts marques: 0.78947368421052631579 - moyenne buts encais 1.7894736842105263 )
# Liverpool ( moyenne buts marques: 2.2105263157894737 - moyenne buts encais 0.84210526315789473684 )

# %% [markdown]
# Classement des équipes (victoire = 3 pts, nul = 1 pt)

# %%
from sqlalchemy import case

stmt = select(
    team.c.team_name,
    func.sum(
        case((match_result.c.Result == 'W', 3),
              (match_result.c.Result == 'D', 1), else_=0)
    ).label("points")
).join(match, match.c.team_id == team.c.team_id
).join(match_result, match_result.c.match_id == match.c.match_id
).group_by(team.c.team_name
).order_by(desc("points"))

with engine.connect() as conn:
    results = conn.execute(stmt).fetchall()
print("Classement des equipes")
for team_name, points in results:
    print(f" {team_name}  {points} points")
# Out:
# Classement des equipes
#  Liverpool  46 points
#  Manchester City  42 points
#  Chelsea  41 points
#  Aston Villa  40 points
#  Arsenal  39 points
#  Newcastle Utd  38 points
#  Nott'ham Forest  32 points
#  Brighton  32 points
#  Brentford  31 points
#  Bournemouth  28 points
#  Fulham  26 points
#  Crystal Palace  25 points
#  Everton  24 points
#  Manchester Utd  24 points
#  Wolves  21 points
#  Tottenham  21 points
#  West Ham  20 points
#  Leicester City  15 points
#  Ipswich Town  7 points
#  Southampton  6 points

# %% [markdown]
# Équipes avec la meilleure défense (moins de buts encaissés)

# %%
stmt = select(
    team.c.team_name,
    func.sum(match_result.c.GA).label("buts_encaisses")
).join(match, match.c.team_id == team.c.team_id
).join(match_result, match_result.c.match_id == match.c.match_id
).group_by(team.c.team_name
).order_by("buts_encaisses")

with engine.connect() as conn:
    results = conn.execute(stmt).fetchall()

for team_name, buts_encaisses in results:
    print(f"{team_name} ({buts_encaisses}) -  buts encaisses")
# Out:
# Bournemouth (16) -  buts encaisses
# Nott'ham Forest (16) -  buts encaisses
# Liverpool (16) -  buts encaisses
# Arsenal (17) -  buts encaisses
# Chelsea (18) -  buts encaisses
# Aston Villa (20) -  buts encaisses
# Newcastle Utd (20) -  buts encaisses
# Manchester City (23) -  buts encaisses
# Everton (23) -  buts encaisses
# Crystal Palace (26) -  buts encaisses
# Brighton (26) -  buts encaisses
# Manchester Utd (28) -  buts encaisses
# Fulham (30) -  buts encaisses
# Wolves (32) -  buts encaisses
# West Ham (34) -  buts encaisses
# Leicester City (34) -  buts encaisses
# Tottenham (35) -  buts encaisses
# Brentford (35) -  buts encaisses
# Ipswich Town (44) -  buts encaisses
# Southampton (47) -  buts encaisses

# %% [markdown]
# Meilleurs buteurs par équipe

# %%
from sqlalchemy import select, func, desc

stmt = (
    select(
        team.c.team_name,
        player.c.Player,
        func.sum(player_statistics.c.Gls).label("total_buts")
    )
    .join(player, player.c.team_id == team.c.team_id)
    .join(player_statistics, player_statistics.c.player_id == player.c.player_id)
    .group_by(team.c.team_name, player.c.Player)
    .order_by(team.c.team_name, desc("total_buts"))
)

with engine.connect() as conn:
    result = conn.execute(stmt).fetchall()
    for row in result:
        print(row)
# Out:
# ('Arsenal', 'Kai Havertz', 18.0)
# ('Arsenal', 'Gabriel Martinelli', 16.0)
# ('Arsenal', 'Leandro Trossard', 16.0)
# ('Arsenal', 'Mikel Merino', 14.0)
# ('Arsenal', 'Bukayo Saka', 12.0)
# ('Arsenal', 'Thomas Partey', 8.0)
# ('Arsenal', 'Ethan Nwaneri', 8.0)
# ('Arsenal', 'Declan Rice', 8.0)
# ('Arsenal', 'Gabriel Jesus', 6.0)
# ('Arsenal', 'Gabriel Magalhães', 6.0)
# ('Arsenal', 'Martin Ødegaard', 6.0)
# ('Arsenal', 'William Saliba', 4.0)
# ('Arsenal', 'Riccardo Calafiori', 4.0)
# ('Arsenal', 'Myles Lewis-Skelly', 2.0)
# ('Arsenal', 'Jakub Kiwior', 2.0)
# ('Arsenal', 'Jurriën Timber', 2.0)
# ('Arsenal', 'Kieran Tierney', 2.0)
# ('Arsenal', 'Ismeal Kabia', 0.0)
# ('Arsenal', 'Takehiro Tomiyasu', 0.0)
# ('Arsenal', 'Tommy Setford', 0.0)
# ('Arsenal', 'Jorginho', 0.0)
# ('Arsenal', 'David Raya', 0.0)
# ('Arsenal', 'Oleksandr Zinchenko', 0.0)
# ('Arsenal', 'Nathan Butler-Oyedeji', 0.0)
# ('Arsenal', 'Reiss Nelson', 0.0)
# ('Arsenal', 'Jimi Gower', 0.0)
# ('Arsenal', 'Jack Henry-Francis', 0.0)
# ('Arsenal', 'Ben White', 0.0)
# ('Arsenal', 'Neto', 0.0)
# ('Arsenal', 'Brayden Clarke', 0.0)
# ('Arsenal', "Salah Oulad M'Hand", 0.0)
# ('Arsenal', 'Raheem Sterling', 0.0)
# ('Arsenal', 'Eddie Nketiah', 0.0)
# ('Arsenal', 'Jack Porter', 0.0)
# ('Arsenal', 'Maldini Kacurri', 0.0)
# ('Arsenal', 'Josh Nichols', 0.0)
# ('Arsenal', 'Ayden Heaven', 0.0)
# ('Arsenal', 'Aaron Ramsdale', 0.0)
# ('Aston Villa', 'Ollie Watkins', 32.0)
# ('Aston Villa', 'Morgan Rogers', 16.0)
# ('Aston Villa', 'Jáder Durán', 14.0)
# ('Aston Villa', 'Youri Tielemans', 6.0)
# ('Aston Villa', 'Donyell Malen', 6.0)
# ('Aston Villa', 'Amadou Onana', 6.0)
# ('Aston Villa', 'Ross Barkley', 6.0)
# ('Aston Villa', 'Marco Asensio', 6.0)
# ('Aston Villa', 'Ezri Konsa', 4.0)
# ('Aston Villa', 'Marcus Rashford', 4.0)
# ('Aston Villa', 'Jacob Ramsey', 2.0)
# ('Aston Villa', 'Ian Maatsen', 2.0)
# ('Aston Villa', 'Leon Bailey', 2.0)
# ('Aston Villa', 'Matty Cash', 2.0)
# ('Aston Villa', 'John McGinn', 2.0)
# ('Aston Villa', 'Boubacar Kamara', 2.0)
# ('Aston Villa', 'Jamaldeen Jimoh', 0.0)
# ('Aston Villa', 'Emiliano Martínez', 0.0)
# ('Aston Villa', 'Tyrone Mings', 0.0)
# ('Aston Villa', 'Jaden Philogene Bidace', 0.0)
# ('Aston Villa', 'Pau Torres', 0.0)
# ('Aston Villa', 'Kosta Nedeljković', 0.0)
# ('Aston Villa', 'Oliwier Zych', 0.0)
# ('Aston Villa', 'Joe Gauci', 0.0)
# ('Aston Villa', 'Kadan Young', 0.0)
# ('Aston Villa', 'Andrés García', 0.0)
# ('Aston Villa', 'Robin Olsen', 0.0)
# ('Aston Villa', 'Lucas Digne', 0.0)
# ('Aston Villa', 'Benjamin Broggio', 0.0)
# ('Aston Villa', 'Diego Carlos', 0.0)
# ('Aston Villa', 'Axel Disasi', 0.0)
# ('Aston Villa', 'Emi Buendía', 0.0)
# ('Aston Villa', 'Lamare Bogarde', 0.0)
# ('Aston Villa', 'Sil Swinkels', 0.0)
# ('Bournemouth', 'Justin Kluivert', 24.0)
# ('Bournemouth', 'Antoine Semenyo', 22.0)
# ('Bournemouth', 'Evanilson', 20.0)
# ('Bournemouth', 'Dango Ouattara', 14.0)
# ('Bournemouth', 'Marcus Tavernier', 6.0)
# ('Bournemouth', 'Dean Huijsen', 6.0)
# ('Bournemouth', 'Milos Kerkez', 4.0)
# ('Brentford', 'Tony Yogane', 0.0)
# ('Brentford', 'Michael Kayode', 0.0)
# ('Brentford', 'Mathias Jensen', 0.0)
# ('Brentford', 'Ben Mee', 0.0)
# ('Brentford', 'Mark Flekken', 0.0)
# ('Brentford', 'Aaron Hickey', 0.0)
# ('Brentford', 'Gustavo Nunes', 0.0)
# ('Brentford', 'Mads Roerslev', 0.0)
# ('Brighton', 'João Pedro', 20.0)
# ('Brighton', 'Kaoru Mitoma', 20.0)
# ('Brighton', 'Danny Welbeck', 20.0)
# ('Brighton', 'Yankuba Minteh', 12.0)
# ('Brighton', 'Georginio Rutter', 10.0)
# ('Brighton', 'Jack Hinshelwood', 10.0)
# ('Brighton', 'Carlos Baleba', 6.0)
# ('Brighton', 'Yasin Ayari', 4.0)
# ('Brighton', 'Tariq Lamptey', 4.0)
# ('Brighton', "Matt O'Riley", 4.0)
# ('Brighton', 'Simon Adingra', 4.0)
# ('Brighton', 'Ferdi Kadioglu', 2.0)
# ('Brighton', 'Diego Gómez', 2.0)
# ('Brighton', 'Jan Paul van Hecke', 2.0)
# ('Brighton', 'Mats Wieffer', 2.0)
# ('Brighton', 'Pervis Estupiñán', 2.0)
# ('Brighton', 'Brajan Gruda', 2.0)
# ('Brighton', 'Evan Ferguson', 2.0)
# ('Brighton', 'Lewis Dunk', 0.0)
# ('Brighton', 'Charlie Tasker', 0.0)
# ('Brighton', 'Joël Veltman', 0.0)
# ('Brighton', 'Jason Steele', 0.0)
# ('Brighton', 'Jacob Slater', 0.0)
# ('Brighton', 'Solly March', 0.0)
# ('Brighton', 'Eiran Cashin', 0.0)
# ('Brighton', 'Adam Webster', 0.0)
# ('Brighton', 'Billy Gilmour', 0.0)
# ('Brighton', 'Carl Rushworth', 0.0)
# ('Brighton', 'Jeremy Sarmiento', 0.0)
# ('Brighton', 'Imari Samuels', 0.0)
# ('Brighton', "Mark O'Mahony", 0.0)
# ('Brighton', 'Valentín Barco', 0.0)
# ('Brighton', 'Igor', 0.0)
# ('Brighton', 'Bart Verbruggen', 0.0)
# ('Brighton', 'Ruairi Mcconville', 0.0)
# ('Brighton', 'Julio Enciso', 0.0)
# ('Brighton', 'Freddie Simmonds', 0.0)
# ('Brighton', 'Killian Cahill', 0.0)
# ('Brighton', 'Joe Knight', 0.0)
# ('Brighton', 'Harry Howell', 0.0)
# ('Brighton', 'James Milner', 0.0)
# ('Brighton', 'Jakub Moder', 0.0)
# ('Chelsea', 'Cole Palmer', 30.0)
# ('Chelsea', 'Nicolas Jackson', 20.0)
# ('Chelsea', 'Noni Madueke', 14.0)
# ('Chelsea', 'Enzo Fernández', 12.0)
# ('Chelsea', 'Marc Cucurella', 10.0)
# ('Chelsea', 'Pedro Neto', 8.0)
# ('Chelsea', 'Christopher Nkunku', 6.0)
# ('Chelsea', 'Jadon Sancho', 6.0)
# ('Chelsea', 'Levi Colwill', 4.0)
# ('Chelsea', 'Tyrique George', 2.0)
# ('Chelsea', 'João Félix', 2.0)
# ('Chelsea', 'Tosin Adarabioyo', 2.0)
# ('Chelsea', 'Reece James', 2.0)
# ('Chelsea', 'Moisés Caicedo', 2.0)
# ('Chelsea', 'Benoît Badiashile', 0.0)
# ('Chelsea', 'Cesare Casadei', 0.0)
# ('Chelsea', 'Renato Veiga', 0.0)
# ('Chelsea', 'Wesley Fofana', 0.0)
# ('Chelsea', 'Samuel Rak-Sakyi', 0.0)
# ('Chelsea', 'Genesis Antwi', 0.0)
# ('Chelsea', 'Aaron Anselmino', 0.0)
# ('Chelsea', 'Joshua Acheampong', 0.0)
# ('Chelsea', 'Ishé Samuels-Smith', 0.0)
# ('Chelsea', 'Marc Guiu', 0.0)
# ('Chelsea', 'Mathis Amougou', 0.0)
# ('Chelsea', 'Kiernan Dewsbury-Hall', 0.0)
# ('Chelsea', 'Mykhailo Mudryk', 0.0)
# ('Chelsea', 'Robert Sánchez', 0.0)
# ('Chelsea', 'Marcus Bettinelli', 0.0)
# ('Chelsea', 'Filip Jørgensen', 0.0)
# ('Chelsea', 'Shumaira Mheuka', 0.0)
# ('Chelsea', 'Malo Gusto', 0.0)
# ('Chelsea', 'Axel Disasi', 0.0)
# ('Chelsea', 'Trevoh Chalobah', 0.0)
# ('Chelsea', 'Roméo Lavia', 0.0)
# ('Crystal Palace', 'Jean-Philippe Mateta', 28.0)
# ('Crystal Palace', 'Ismaila Sarr', 16.0)
# ('Crystal Palace', 'Eberechi Eze', 16.0)
# ('Crystal Palace', 'Daniel Muñoz', 8.0)
# ('Crystal Palace', 'Marc Guéhi', 6.0)
# ('Crystal Palace', 'Ben Chilwell', 2.0)
# ('Crystal Palace', 'Romain Esse', 2.0)
# ('Crystal Palace', 'Maxence Lacroix', 2.0)
# ('Crystal Palace', 'Chris Richards', 2.0)
# ('Crystal Palace', 'Justin Devenny', 2.0)
# ('Crystal Palace', 'Matheus França', 2.0)
# ('Crystal Palace', 'Nathaniel Clyne', 0.0)
# ('Crystal Palace', 'Sam Johnstone', 0.0)
# ('Crystal Palace', 'Dean Henderson', 0.0)
# ('Crystal Palace', 'Odsonne Édouard', 0.0)
# ('Crystal Palace', 'Adam Wharton', 0.0)
# ('Crystal Palace', 'Caleb Kporha', 0.0)
# ('Crystal Palace', 'Daichi Kamada', 0.0)
# ('Crystal Palace', 'Chadi Riad', 0.0)
# ('Crystal Palace', 'Will Hughes', 0.0)
# ('Crystal Palace', 'Tyrick Mitchell', 0.0)
# ('Crystal Palace', 'Matt Turner', 0.0)
# ('Crystal Palace', 'Naouirou Ahamada', 0.0)
# ('Crystal Palace', 'Eddie Nketiah', 0.0)
# ('Crystal Palace', 'Jefferson Lerma', 0.0)
# ('Crystal Palace', 'Rob Holding', 0.0)
# ('Crystal Palace', 'Cheick Doucouré', 0.0)
# ('Crystal Palace', 'Remi Matthews', 0.0)
# ('Crystal Palace', 'Jeffrey Schlupp', 0.0)
# ('Crystal Palace', 'Joachim Andersen', 0.0)
# ('Crystal Palace', 'Asher Agbinone', 0.0)
# ('Crystal Palace', 'Kaden Rodney', 0.0)
# ('Fulham', 'Willian', 0.0)
# ('Fulham', 'Reiss Nelson', 0.0)
# ('Fulham', 'Carlos Vinícius', 0.0)
# ('Fulham', 'Antonee Robinson', 0.0)
# ('Fulham', 'Samuel Amissah', 0.0)
# ('Fulham', 'Joachim Andersen', 0.0)
# ('Ipswich Town', 'Liam Delap', 24.0)
# ('Ipswich Town', 'Sammie Szmodics', 8.0)
# ('Ipswich Town', 'Omari Hutchinson', 6.0)
# ('Ipswich Town', 'George Hirst', 6.0)
# ('Ipswich Town', 'Nathan Broadhead', 4.0)
# ('Ipswich Town', 'Jacob Greaves', 2.0)
# ('Ipswich Town', 'Jens Cajuste', 2.0)
# ('Ipswich Town', 'Ben Johnson', 2.0)
# ('Ipswich Town', 'Leif Davis', 2.0)
# ('Ipswich Town', 'Jack Taylor', 2.0)
# ('Ipswich Town', 'Conor Chaplin', 2.0)
# ('Ipswich Town', 'Sam Morsy', 2.0)
# ('Ipswich Town', 'Marcus Harness', 0.0)
# ('Ipswich Town', 'Jaden Philogene Bidace', 0.0)
# ('Ipswich Town', 'Luke Woolfenden', 0.0)
# ('Ipswich Town', 'Ben Godfrey', 0.0)
# ('Ipswich Town', 'Axel Tuanzebe', 0.0)
# ('Ipswich Town', 'Jack Clarke', 0.0)
# ('Ipswich Town', 'Kalvin Phillips', 0.0)
# ('Ipswich Town', 'George Edmundson', 0.0)
# ('Ipswich Town', 'Alex Palmer', 0.0)
# ('Ipswich Town', 'Cameron Burgess', 0.0)
# ('Ipswich Town', "Dara O'Shea", 0.0)
# ('Ipswich Town', 'Conor Townsend', 0.0)
# ('Ipswich Town', 'Ali Al Hamadi', 0.0)
# ('Ipswich Town', 'Christian Walton', 0.0)
# ('Ipswich Town', 'Cieran Slicker', 0.0)
# ('Ipswich Town', 'Harry Clarke', 0.0)
# ('Ipswich Town', 'Tom Taylor', 0.0)
# ('Ipswich Town', 'Julio Enciso', 0.0)
# ('Ipswich Town', 'Massimo Luongo', 0.0)
# ('Ipswich Town', 'Arijanet Muric', 0.0)
# ('Ipswich Town', 'Chiedozie Ogbene', 0.0)
# ('Ipswich Town', 'Wes Burns', 0.0)
# ('Ipswich Town', 'Somto Boniface', 0.0)
# ('Leicester City', 'Jamie Vardy', 18.0)
# ('Leicester City', 'Facundo Buonanotte', 10.0)
# ('Leicester City', 'Stephy Mavididi', 8.0)
# ('Leicester City', 'James Justin', 4.0)
# ('Leicester City', 'Bilal El Khannouss', 4.0)
# ('Leicester City', 'Conor Coady', 2.0)
# ('Leicester City', 'Caleb Okoli', 2.0)
# ('Leicester City', 'Bobby De Cordova-Reid', 2.0)
# ('Leicester City', 'Wout Faes', 2.0)
# ('Leicester City', 'Kasey McAteer', 2.0)
# ('Leicester City', 'Patson Daka', 2.0)
# ('Leicester City', 'Sammy Braybrooke', 0.0)
# ('Leicester City', 'Harry Winks', 0.0)
# ('Leicester City', 'Woyo Coulibaly', 0.0)
# ('Leicester City', 'Olabade Aluko', 0.0)
# ('Leicester City', 'Jake Evans', 0.0)
# ('Leicester City', 'Benjamin Nelson', 0.0)
# ('Leicester City', 'Jeremy Monga', 0.0)
# ('Leicester City', 'Victor Bernth Kristiansen', 0.0)
# ('Leicester City', 'Wilfred Ndidi', 0.0)
# ('Leicester City', 'Jordan Ayew', 0.0)
# ('Leicester City', 'Henry Cartwright', 0.0)
# ('Leicester City', 'Hamza Choudhury', 0.0)
# ('Leicester City', 'Odsonne Édouard', 0.0)
# ('Leicester City', 'Will Alves', 0.0)
# ('Leicester City', 'Danny Ward', 0.0)
# ('Leicester City', 'Luke Thomas', 0.0)
# ('Leicester City', 'Abdul Fatawu Issahaku', 0.0)
# ('Leicester City', 'Boubakary Soumaré', 0.0)
# ('Leicester City', 'Oliver Skipp', 0.0)
# ('Leicester City', 'Jakub Stolarczyk', 0.0)
# ('Leicester City', 'Ricardo Pereira', 0.0)
# ('Leicester City', 'Michael Golding', 0.0)
# ('Leicester City', 'Thomas Wilson-Brown', 0.0)
# ('Leicester City', 'Daniel Iversen', 0.0)
# ('Leicester City', 'Thomas Cannon', 0.0)
# ('Leicester City', 'Jannik Vestergaard', 0.0)
# ('Leicester City', 'Mads Hermansen', 0.0)
# ('Liverpool', 'Mohamed Salah', 58.0)
# ('Liverpool', 'Luis Díaz', 26.0)
# ('Liverpool', 'Cody Gakpo', 20.0)
# ('Liverpool', 'Diogo Jota', 12.0)
# ('Liverpool', 'Dominik Szoboszlai', 12.0)
# ('Liverpool', 'Alexis Mac Allister', 10.0)
# ('Liverpool', 'Darwin Núñez', 10.0)
# ('Liverpool', 'Trent Alexander-Arnold', 6.0)
# ('Liverpool', 'Curtis Jones', 6.0)
# ('Liverpool', 'Virgil van Dijk', 6.0)
# ('Liverpool', 'Ibrahima Konaté', 2.0)
# ('Liverpool', 'Harvey Elliott', 2.0)
# ('Liverpool', 'Jayden Danns', 0.0)
# ('Liverpool', 'Wataru Endo', 0.0)
# ('Liverpool', 'Vitezslav Jaros', 0.0)
# ('Liverpool', 'James McConnell', 0.0)
# ('Liverpool', 'Amara Nallo', 0.0)
# ('Liverpool', 'Tyler Morton', 0.0)
# ('Liverpool', 'Caoimhín Kelleher', 0.0)
# ('Liverpool', 'Ryan Gravenberch', 0.0)
# ('Liverpool', 'Trey Nyoni', 0.0)
# ('Liverpool', 'Alisson', 0.0)
# ('Liverpool', 'Kostas Tsimikas', 0.0)
# ('Liverpool', 'Andrew Robertson', 0.0)
# ('Liverpool', 'Jarell Quansah', 0.0)
# ('Liverpool', 'Federico Chiesa', 0.0)
# ('Liverpool', 'Harvey Davies', 0.0)
# ('Liverpool', 'Conor Bradley', 0.0)
# ('Liverpool', 'Joe Gomez', 0.0)
# ('Manchester City', 'Erling Haaland', 44.0)
# ('Manchester City', 'Omar Marmoush', 14.0)
# ('Manchester City', 'Phil Foden', 14.0)
# ('Manchester City', 'Mateo Kovačić', 12.0)
# ('Manchester City', 'Joško Gvardiol', 10.0)
# ('Manchester City', 'Kevin De Bruyne', 8.0)
# ('Manchester City', 'Bernardo Silva', 8.0)
# ('Manchester City', 'James Mcatee', 6.0)
# ('Manchester City', 'Jeremy Doku', 6.0)
# ('Manchester City', 'John Stones', 4.0)
# ('Manchester City', 'Nico O’Reilly', 4.0)
# ('Manchester City', 'Matheus Nunes', 2.0)
# ('Manchester City', 'İlkay Gündoğan', 2.0)
# ('Manchester City', 'Jack Grealish', 2.0)
# ('Manchester City', 'Nicolás González', 2.0)
# ('Manchester City', 'Rico Lewis', 2.0)
# ('Manchester City', 'Sávio', 2.0)
# ('Manchester City', 'Oscar Bobb', 0.0)
# ('Manchester City', 'Claudio Echeverri', 0.0)
# ('Manchester City', 'Rúben Dias', 0.0)
# ('Manchester City', 'Manuel Akanji', 0.0)
# ('Manchester City', 'Issa Kaboré', 0.0)
# ('Manchester City', 'Stefan Ortega', 0.0)
# ('Manchester City', 'Scott Carson', 0.0)
# ('Manchester City', 'Vitor Reis', 0.0)
# ('Manchester City', 'Jahmai Simpson-Pusey', 0.0)
# ('Manchester City', 'Abdukodir Khusanov', 0.0)
# ('Manchester City', 'Jacob Wright', 0.0)
# ('Manchester City', 'Divin Mubama', 0.0)
# ('Manchester City', 'Rodri', 0.0)
# ('Manchester City', 'Thorsten Brits', 0.0)
# ('Manchester City', 'Ederson', 0.0)
# ('Manchester City', 'Nathan Aké', 0.0)
# ('Manchester City', 'Josh Wilson-Esbrand', 0.0)
# ('Manchester City', 'Max Alleyne', 0.0)
# ('Manchester City', 'Kyle Walker', 0.0)
# ('Manchester Utd', 'Amad Diallo', 16.0)
# ('Manchester Utd', 'Bruno Fernandes', 16.0)
# ('Manchester Utd', 'Alejandro Garnacho', 12.0)
# ('Manchester Utd', 'Rasmus Højlund', 8.0)
# ('Manchester Utd', 'Joshua Zirkzee', 6.0)
# ('Manchester Utd', 'Matthijs de Ligt', 4.0)
# ('Manchester Utd', 'Lisandro Martínez', 4.0)
# ('Manchester Utd', 'Marcus Rashford', 4.0)
# ('Manchester Utd', 'Christian Eriksen', 2.0)
# ('Manchester Utd', 'Mason Mount', 2.0)
# ('Manchester Utd', 'Casemiro', 2.0)
# ('Manchester Utd', 'Manuel Ugarte', 2.0)
# ('Manchester Utd', 'Harry Maguire', 2.0)
# ('Manchester Utd', 'Ethan Wheatley', 0.0)
# ('Manchester Utd', 'Sekou Koné', 0.0)
# ('Manchester Utd', 'Patrick Dorgu', 0.0)
# ('Manchester Utd', 'Kobbie Mainoo', 0.0)
# ('Manchester Utd', 'Ayden Heaven', 0.0)
# ('Manchester Utd', 'Noussair Mazraoui', 0.0)
# ('Manchester Utd', 'Leny Yoro', 0.0)
# ('Manchester Utd', 'André Onana', 0.0)
# ('Manchester Utd', 'Jonny Evans', 0.0)
# ('Manchester Utd', 'Tyler Fredricson', 0.0)
# ('Manchester Utd', 'Jack Moorhouse', 0.0)
# ('Manchester Utd', 'Toby Collyer', 0.0)
# ('Manchester Utd', 'Altay Bayındır', 0.0)
# ('Manchester Utd', 'Victor Lindelöf', 0.0)
# ('Manchester Utd', 'Harry Amass', 0.0)
# ('Manchester Utd', 'Antony', 0.0)
# ('Manchester Utd', 'Godwill Kukonki', 0.0)
# ('Manchester Utd', 'Jack Fletcher', 0.0)
# ('Manchester Utd', 'Luke Shaw', 0.0)
# ('Manchester Utd', 'Chidozie Obi-Martin', 0.0)
# ('Manchester Utd', 'Tyrell Malacia', 0.0)
# ('Manchester Utd', 'Elyh Harrison', 0.0)
# ('Manchester Utd', 'Dermot Mee', 0.0)
# ('Manchester Utd', 'Tom Heaton', 0.0)
# ('Manchester Utd', 'Hubert Graczyk', 0.0)
# ('Manchester Utd', 'Scott McTominay', 0.0)
# ('Manchester Utd', 'Jayce Fitzgerald', 0.0)
# ('Manchester Utd', 'Diogo Dalot', 0.0)
# ('Newcastle Utd', 'Alexander Isak', 46.0)
# ('Newcastle Utd', 'Harvey Barnes', 18.0)
# ('Newcastle Utd', 'Jacob Murphy', 16.0)
# ('Newcastle Utd', 'Anthony Gordon', 12.0)
# ('Newcastle Utd', 'Bruno Guimarães', 10.0)
# ('Newcastle Utd', 'Joelinton', 8.0)
# ('Newcastle Utd', 'Sandro Tonali', 8.0)
# ('Newcastle Utd', 'Fabian Schär', 8.0)
# ('Newcastle Utd', 'William Osula', 2.0)
# ('Newcastle Utd', 'Dan Burn', 2.0)
# ('Newcastle Utd', 'Lewis Miley', 2.0)
# ('Newcastle Utd', 'Sven Botman', 0.0)
# ('Newcastle Utd', 'Martin Dúbravka', 0.0)
# ('Newcastle Utd', 'Leo Shahar', 0.0)
# ('Newcastle Utd', 'Lloyd Kelly', 0.0)
# ('Newcastle Utd', 'Emil Krafth', 0.0)
# ('Newcastle Utd', 'Kieran Trippier', 0.0)
# ('Newcastle Utd', 'Sean Longstaff', 0.0)
# ('Newcastle Utd', 'John Ruddy', 0.0)
# ('Newcastle Utd', 'Joe Willock', 0.0)
# ('Newcastle Utd', 'Matt Targett', 0.0)
# ('Newcastle Utd', 'Sean Neave', 0.0)
# ('Newcastle Utd', 'Miguel Almirón', 0.0)
# ('Newcastle Utd', 'Odysseas Vlachodimos', 0.0)
# ('Newcastle Utd', 'Valentino Livramento', 0.0)
# ('Newcastle Utd', 'Jamaal Lascelles', 0.0)
# ('Newcastle Utd', 'Callum Wilson', 0.0)
# ('Newcastle Utd', 'Nick Pope', 0.0)
# ('Newcastle Utd', 'Alex Murphy', 0.0)
# ('Newcastle Utd', 'Lewis Hall', 0.0)
# ("Nott'ham Forest", 'Chris Wood', 40.0)
# ("Nott'ham Forest", 'Morgan Gibbs-White', 14.0)
# ("Nott'ham Forest", 'Anthony Elanga', 12.0)
# ("Nott'ham Forest", 'Callum Hudson-Odoi', 10.0)
# ("Nott'ham Forest", 'Nikola Milenković', 10.0)
# ("Nott'ham Forest", 'Jota Silva', 6.0)
# ("Nott'ham Forest", 'Ola Aina', 4.0)
# ("Nott'ham Forest", 'Ryan Yates', 4.0)
# ("Nott'ham Forest", 'Murillo', 4.0)
# ("Nott'ham Forest", 'Elliot Anderson', 4.0)
# ("Nott'ham Forest", 'Ramón Sosa', 2.0)
# ("Nott'ham Forest", 'Neco Williams', 2.0)
# ("Nott'ham Forest", 'Taiwo Awoniyi', 2.0)
# ("Nott'ham Forest", 'Álex Moreno', 0.0)
# ("Nott'ham Forest", 'Carlos Miguel', 0.0)
# ("Nott'ham Forest", 'Eric da Silva Moreira', 0.0)
# ("Nott'ham Forest", 'Andrew Omobamidele', 0.0)
# ("Nott'ham Forest", 'Matz Sels', 0.0)
# ("Nott'ham Forest", 'Ibrahim Sangaré', 0.0)
# ("Nott'ham Forest", 'Wayne Hennessey', 0.0)
# ("Nott'ham Forest", 'Willy Boly', 0.0)
# ("Nott'ham Forest", 'Zach Abbott', 0.0)
# ("Nott'ham Forest", 'James Ward-Prowse', 0.0)
# ("Nott'ham Forest", 'Danilo', 0.0)
# ("Nott'ham Forest", 'Nicolás Domínguez', 0.0)
# ("Nott'ham Forest", 'Morato', 0.0)
# ("Nott'ham Forest", 'Harry Toffolo', 0.0)
# ('Southampton', 'Paul Onuachu', 8.0)
# ('Southampton', 'Joe Aribo', 6.0)
# ('Southampton', 'Jan Bednarek', 4.0)
# ('Southampton', 'Adam Armstrong', 4.0)
# ('Southampton', 'Tyler Dibling', 4.0)
# ('Southampton', 'Cameron Archer', 4.0)
# ('Southampton', 'Mateus Fernandes', 4.0)
# ('Southampton', 'Carlos Alcaraz', 4.0)
# ('Southampton', 'Lesley Ugochukwu', 2.0)
# ('Southampton', 'Yukinari Sugawara', 2.0)
# ('Southampton', 'Jack Stephens', 2.0)
# ('Southampton', 'William Smallbone', 2.0)
# ('Southampton', 'Kamaldeen Sulemana', 2.0)
# ('Southampton', 'Flynn Downes', 2.0)
# ('Southampton', 'Taylor Harwood-Bellis', 2.0)
# ('Southampton', 'Ross Stewart', 2.0)
# ('Southampton', 'Ryan Fraser', 0.0)
# ('Southampton', 'Jayden Moore', 0.0)
# ('Southampton', 'Joe Lumley', 0.0)
# ('Southampton', 'Maxwel Cornet', 0.0)
# ('Southampton', 'Ben Brereton', 0.0)
# ('Southampton', 'Adam Lallana', 0.0)
# ('Southampton', 'Ryan Manning', 0.0)
# ('Southampton', 'Jay Robinson', 0.0)
# ('Southampton', 'Alex McCarthy', 0.0)
# ('Southampton', 'Ronnie Edwards', 0.0)
# ('Southampton', 'Armel Bella Kotchap', 0.0)
# ('Southampton', 'Charlie Taylor', 0.0)
# ('Southampton', 'Aaron Ramsdale', 0.0)
# ('Southampton', 'Samuel Edozie', 0.0)
# ('Southampton', 'Samuel Amo-Ameyaw', 0.0)
# ('Southampton', 'Welington', 0.0)
# ('Southampton', 'James Bree', 0.0)
# ('Southampton', 'Albert Grønbaek', 0.0)
# ('Southampton', 'Kyle Walker-Peters', 0.0)
# ('Southampton', 'Joachim Kayi Sanda', 0.0)
# ('Southampton', "Joe O'Brien-Whitmarsh", 0.0)
# ('Southampton', 'Nathan Wood-Gordon', 0.0)
# ('Tottenham', 'Brennan Johnson', 22.0)
# ('Tottenham', 'Dominic Solanke', 18.0)
# ('Tottenham', 'James Maddison', 18.0)
# ('Tottenham', 'Son Heung-min', 14.0)
# ('Tottenham', 'Dejan Kulusevski', 14.0)
# ('Tottenham', 'Richarlison', 8.0)
# ('Tottenham', 'Pape Matar Sarr', 6.0)
# ('Tottenham', 'Rodrigo Bentancur', 4.0)
# ('Tottenham', 'Yves Bissouma', 4.0)
# ('Tottenham', 'Mathys Tel', 4.0)
# ('Tottenham', 'Pedro Porro', 4.0)
# ('Tottenham', 'Cristian Romero', 2.0)
# ('Tottenham', 'Djed Spence', 2.0)
# ('Tottenham', 'Wilson Odobert', 2.0)
# ('Tottenham', 'Dane Scarlett', 0.0)
# ('Tottenham', 'Sergio Reguilón', 0.0)
# ('Tottenham', 'Ben Davies', 0.0)
# ('Tottenham', 'Alfie Whiteman', 0.0)
# ('Tottenham', 'Alfie Devine', 0.0)
# ('Tottenham', 'Destiny Udogie', 0.0)
# ('Tottenham', 'Timo Werner', 0.0)
# ('Tottenham', 'Callum Olusesi', 0.0)
# ('Tottenham', 'Guglielmo Vicario', 0.0)
# ('Tottenham', 'Dante Cassanova', 0.0)
# ('Tottenham', 'Micky van de Ven', 0.0)
# ('Tottenham', 'Lucas Bergvall', 0.0)
# ('Tottenham', 'Yang Minhyeok', 0.0)
# ('Tottenham', 'Brandon Austin', 0.0)
# ('Tottenham', 'Alfie Dorrington', 0.0)
# ('Tottenham', 'Kevin Danso', 0.0)
# ('Tottenham', 'Malachi Hardy', 0.0)
# ('Tottenham', 'Luca Williams Barnett', 0.0)
# ('Tottenham', 'Radu Drăgușin', 0.0)
# ('Tottenham', 'Archie Gray', 0.0)
# ('Tottenham', 'Will Lankshear', 0.0)
# ('Tottenham', 'Maeson King', 0.0)
# ('Tottenham', 'Mikey Moore', 0.0)
# ('Tottenham', 'Oyindamola Ajayi', 0.0)
# ('Tottenham', 'Antonín Kinský', 0.0)
# ('Tottenham', 'Fraser Forster', 0.0)
# ('West Ham', 'Jarrod Bowen', 26.0)
# ('West Ham', 'Tomáš Souček', 18.0)
# ('West Ham', 'Mohammed Kudus', 10.0)
# ('West Ham', 'Lucas Paquetá', 8.0)
# ('West Ham', 'Niclas Füllkrug', 6.0)
# ('West Ham', 'Aaron Wan-Bissaka', 4.0)
# ('West Ham', 'Emerson Palmieri', 4.0)
# ('West Ham', 'Danny Ings', 2.0)
# ('West Ham', 'Michail Antonio', 2.0)
# ('West Ham', 'Evan Ferguson', 2.0)
# ('West Ham', 'Carlos Soler', 2.0)
# ('West Ham', 'Crysencio Summerville', 2.0)
# ('West Ham', 'Lewis Orford', 0.0)
# ('West Ham', 'Kaelan Casey', 0.0)
# ('West Ham', 'Vladimír Coufal', 0.0)
# ('West Ham', 'Aaron Cresswell', 0.0)
# ('West Ham', 'James Ward-Prowse', 0.0)
# ('West Ham', 'Konstantinos Mavropanos', 0.0)
# ('West Ham', 'Guido Rodríguez', 0.0)
# ('West Ham', 'Edson Álvarez', 0.0)
# ('West Ham', 'Jean-Clair Todibo', 0.0)
# ('West Ham', 'Łukasz Fabiański', 0.0)
# ('West Ham', 'Andy Irving', 0.0)
# ('West Ham', 'Max Kilman', 0.0)
# ('West Ham', 'Alphonse Areola', 0.0)
# ('West Ham', 'Wes Foderingham', 0.0)
# ('West Ham', 'Ezra Mayers', 0.0)
# ('West Ham', 'Oliver Scarles', 0.0)
# ('West Ham', 'Luis Guilherme', 0.0)
# ('Wolves', 'Matheus Cunha', 30.0)
# ('Wolves', 'Jørgen Strand Larsen', 28.0)
# ('Wolves', 'Rayan Aït-Nouri', 8.0)
# ('Wolves', 'Pablo Sarabia', 6.0)
# ('Wolves', 'João Gomes', 6.0)
# ('Wolves', 'Jean-Ricner Bellegarde', 4.0)
# ('Wolves', 'Rodrigo Gomes', 4.0)
# ('Wolves', 'Gonçalo Guedes', 4.0)
# ('Wolves', 'Hwang Hee-chan', 4.0)
# ('Wolves', 'Marshall Munetsi', 4.0)
# ('Wolves', 'Matt Doherty', 4.0)
# ('Wolves', 'Emmanuel Agbadou', 2.0)
# ('Wolves', 'Mario Lemina', 2.0)
# ('Wolves', 'Chiquinho', 0.0)
# ('Wolves', 'Nasser Djiga', 0.0)
# ('Wolves', 'Tom Edozie', 0.0)
# ('Wolves', 'Boubacar Traoré', 0.0)
# ('Wolves', 'Daniel Bentley', 0.0)
# ('Wolves', 'Santiago Bueno', 0.0)
# ('Wolves', 'Craig Dawson', 0.0)
# ('Wolves', 'André', 0.0)
# ('Wolves', 'Daniel Podence', 0.0)
# ('Wolves', 'Alfie Pond', 0.0)
# ('Wolves', 'Pedro Lima', 0.0)
# ('Wolves', 'Tommy Doyle', 0.0)
# ('Wolves', 'José Sá', 0.0)
# ('Wolves', 'Tom King', 0.0)
# ('Wolves', 'Nélson Semedo', 0.0)
# ('Wolves', 'Tawanda Chirewa', 0.0)
# ('Wolves', 'Toti Gomes', 0.0)
# ('Wolves', 'Yerson Mosquera', 0.0)
# ('Wolves', 'Luke Cundle', 0.0)
# ('Wolves', 'Sam Johnstone', 0.0)
# ('Wolves', 'Carlos Forbs', 0.0)
# ('Wolves', 'Mateus Mane', 0.0)
# ('Wolves', 'Wesley Okoduwa', 0.0)
# ('Wolves', 'Bastien Meupiyou', 0.0)

# %% [markdown]
# Nombre total de matchs joués par équipe

# %%
stmt = select(
    team.c.team_name,
    func.count(match.c.match_id).label("nb_matchs")
).join(match, match.c.team_id == team.c.team_id
).group_by(team.c.team_name
).order_by(desc("nb_matchs"))

with engine.connect() as conn:
    result = conn.execute(stmt).fetchall()
    for row in result:
        print(row)
# Out:
# ('Bournemouth', 19)
# ("Nott'ham Forest", 19)
# ('Manchester City', 19)
# ('Manchester Utd', 19)
# ('Tottenham', 19)
# ('Everton', 19)
# ('Fulham', 19)
# ('Brentford', 19)
# ('Ipswich Town', 19)
# ('Brighton', 19)
# ('Wolves', 19)
# ('Newcastle Utd', 19)
# ('Aston Villa', 19)
# ('Crystal Palace', 19)
# ('Arsenal', 19)
# ('Southampton', 19)
# ('Chelsea', 19)
# ('West Ham', 19)
# ('Leicester City', 19)
# ('Liverpool', 19)
